# %%
import os
import time
from datetime import datetime, timezone
import requests
import json
import pandas as pd
import numpy as np

from azure.ai.anomalydetector import AnomalyDetectorClient
from azure.ai.anomalydetector.models import ModelInfo
from azure.ai.anomalydetector.models import ModelStatus
from azure.core.credentials import AzureKeyCredential



class MultivariateSample:

    def __init__(self, subscription_key, anomaly_detector_endpoint, data_source=None):
        self.sub_key = subscription_key
        self.end_point = anomaly_detector_endpoint
        # Create an Anomaly Detector client

        # <client>
        self.ad_client = AnomalyDetectorClient(AzureKeyCredential(self.sub_key), self.end_point)
        # </client>

        self.data_source = data_source

    def train(self, start_time, end_time):
        # Number of models available now
        model_list = list(self.ad_client.list_multivariate_model(skip=0, top=10000))
        print("{:d} available models before training.".format(len(model_list)))

        # Use sample data to train the model
        print("Training new model...(it may take a few minutes)")
        data_feed = ModelInfo(start_time=start_time, end_time=end_time, source=self.data_source)
        response_header = \
            self.ad_client.train_multivariate_model(data_feed, cls=lambda *args: [args[i] for i in range(len(args))])[-1]
        trained_model_id = response_header['Location'].split("/")[-1]

        # Wait until the model is ready. It usually takes several minutes
        model_status = None

        while model_status != ModelStatus.READY and model_status != ModelStatus.FAILED:
            model_info = self.ad_client.get_multivariate_model(trained_model_id).model_info
            model_status = model_info.status
            time.sleep(10)

        if model_status == ModelStatus.FAILED:
            print("Creating model failed.")
            print("Errors:")
            if model_info.errors:
                for error in model_info.errors:
                    print("Error code: {}. Message: {}".format(error.code, error.message))
            else:
                print("None")
            return None

        if model_status == ModelStatus.READY:
            # Model list after training
            new_model_list = list(self.ad_client.list_multivariate_model(skip=0, top=10000))

            print("Done.\n--------------------")
            print("{:d} available models after training.".format(len(new_model_list)))

            # Return the latest model id
            return trained_model_id


    def detect(self, model_id, start_time, end_time):
        # Detect anomaly in the same data source (but a different interval)
        try:
            detection_req = DetectionRequest(source=self.data_source, start_time=start_time, end_time=end_time)
            response_header = self.ad_client.detect_anomaly(model_id, detection_req,
                                                            cls=lambda *args: [args[i] for i in range(len(args))])[-1]
            result_id = response_header['Location'].split("/")[-1]

            # Get results (may need a few seconds)
            r = self.ad_client.get_detection_result(result_id)
            print("Get detection result...(it may take a few seconds)")

            while r.summary.status != DetectionStatus.READY and r.summary.status != DetectionStatus.FAILED:
                r = self.ad_client.get_detection_result(result_id)
                time.sleep(1)

            if r.summary.status == DetectionStatus.FAILED:
                print("Detection failed.")
                print("Errors:")
                if r.summary.errors:
                    for error in r.summary.errors:
                        print("Error code: {}. Message: {}".format(error.code, error.message))
                else:
                    print("None")
                return None

        except HttpResponseError as e:
            print('Error code: {}'.format(e.error.code), 'Error message: {}'.format(e.error.message))
        except Exception as e:
            raise e

        return r

    def export_model(self, model_id, model_path="model.zip"):

        # Export the model
        model_stream_generator = self.ad_client.export_model(model_id)
        with open(model_path, "wb") as f_obj:
            while True:
                try:
                    f_obj.write(next(model_stream_generator))
                except StopIteration:
                    break
                except Exception as e:
                    raise e

    def delete_model(self, model_id):

        # Delete the mdoel
        self.ad_client.delete_multivariate_model(model_id)
        model_list_after_delete = list(self.ad_client.list_multivariate_model(skip=0, top=10000))
        print("{:d} available models after deletion.".format(len(model_list_after_delete)))


if __name__ == '__main__':
    
    # SUBSCRIPTION_KEY = os.environ["ANOMALY_DETECTOR_KEY"]
    SUBSCRIPTION_KEY = "ANOMALY_DETECTOR_KEY"
    # ANOMALY_DETECTOR_ENDPOINT = os.environ["ANOMALY_DETECTOR_ENDPOINT"]
    ANOMALY_DETECTOR_ENDPOINT = "ANOMALY_DETECTOR_ENDPOINT"

    # *****************************
    # Use your own data source here
    # *****************************
    data_source = "https://badsboys.blob.core.windows.net/trainingdataanomaly/TrainingData.zip?sp=r&st=2022-06-18T19:16:49Z&se=2022-06-19T03:16:49Z&spr=https&sv=2021-06-08&sr=b&sig=G5O7PzsQLslM%2FIVknMJz1IDZBqWqXJo7WUuWmLNZPB4%3D"
    # Create a new sample and client
    sample = MultivariateSample(SUBSCRIPTION_KEY, ANOMALY_DETECTOR_ENDPOINT, data_source)

    # Train a new model
    model_id = sample.train(datetime(2022, 6, 3, 13, 11, 10, tzinfo=timezone.utc),
                            datetime(2022, 6, 3, 14, 41, 53, tzinfo=timezone.utc))
    assert model_id is not None

    print("Model ID:\t", model_id)
# Out:
# 0 available models before training.
# Training new model...(it may take a few minutes)
# Done.
# --------------------
# 1 available models after training.
# Model ID:	 41a68a3a-ef3e-11ec-9182-4e01098ecd37

# %%
ENDPOINT = "badsboysanomalydetection.cognitiveservices.azure.com/anomalydetector/v1.1-preview.1"
HEADERS = {
    "Ocp-Apim-Subscription-Key": "8ba5b3a75b5d4ee79cf7217d26ca6a38"
}

# %%
API_MODEL_INFERENCE = "https://{endpoint}/multivariate/models/{model_id}/detect"
API_RESULTS = "https://{endpoint}/multivariate/results/{result_id}"
SOURCE_BLOB_SAS = data_source

# %%
data = {
    'source': SOURCE_BLOB_SAS,
    'startTime': '2022-06-03T13:17:54Z', 
    'endTime': '2022-06-03T13:51:06Z', 

    # 'startTime': '2022-06-03T13:43:51Z', 
    # 'endTime': '2022-06-03T14:15:23Z', 
}

res = requests.post(API_MODEL_INFERENCE.format(endpoint=ENDPOINT, model_id=model_id), 
                    data=json.dumps(data), headers=HEADERS)
assert res.status_code == 201, f"Error occured. Error message: {res.content}"

result_id = res.headers['location'].split("/")[-1]

print(res.content)

print(f"result id = {result_id}")
# Out:
# b'"Success"\n'
# result id = 1242349c-ef48-11ec-95dd-da0565d36a5d

# %%
res = requests.get(API_RESULTS.format(endpoint=ENDPOINT, result_id=result_id), headers=HEADERS)
assert res.status_code == 200, f"Error occured. Error message: {res.content}"

status = None
while status != "READY"and status != "FAILED":
    res = requests.get(API_RESULTS.format(endpoint=ENDPOINT, result_id=result_id), headers=HEADERS)
    assert res.status_code == 200, f"Error occured. Error message: {res.content}"

    result = res.json()
    status = result['summary']['status']

    time.sleep(60)

if status == "FAILED":
    print("Detection failed.")
    print("Errors:")
    if res.summary.errors:
        for error in res.summary.errors:
            print("Error code: {}. Message: {}".format(error.code, error.message))
    else:
        print("None")

print('Done')
# Out:
# Done

# %%
columns = {'timestamp':[result['results'][x]['timestamp'] for x in range(len(result['results']))],
'isAnomaly':[result['results'][x]['value']['isAnomaly'] for x in range(len(result['results']))]
}

# %%
response = pd.DataFrame(data=columns)
response.head()
# Out:
#               timestamp  isAnomaly
# 0  2022-06-03T13:17:54Z      False
# 1  2022-06-03T13:17:54Z      False
# 2  2022-06-03T13:17:54Z      False
# 3  2022-06-03T13:17:54Z      False
# 4  2022-06-03T13:17:54Z      False

# %%
response.dropna(inplace=True)
response.head()
# Out:
#               timestamp  isAnomaly
# 0  2022-06-03T13:17:54Z      False
# 1  2022-06-03T13:17:54Z      False
# 2  2022-06-03T13:17:54Z      False
# 3  2022-06-03T13:17:54Z      False
# 4  2022-06-03T13:17:54Z      False

# %%
table = pd.pivot_table(response[['timestamp', 'isAnomaly']], values = ['isAnomaly'], index=['timestamp'],
                    columns=['isAnomaly'], aggfunc=np.count_nonzero)
table.head()
# Out:
# isAnomaly             False  True
# timestamp
# 2022-06-03T13:17:54Z   10.0   NaN
# 2022-06-03T13:17:55Z   10.0   NaN
# 2022-06-03T13:17:56Z   10.0   NaN
# 2022-06-03T13:17:57Z   10.0   NaN
# 2022-06-03T13:17:58Z   10.0   NaN

# %%
table.fillna(0, inplace=True)

# %%
table['Anomaly'] = table[True]>table[False]

# %%
table
# Out:
# isAnomaly             False  True  Anomaly
# timestamp
# 2022-06-03T13:17:54Z   10.0   0.0    False
# 2022-06-03T13:17:55Z   10.0   0.0    False
# 2022-06-03T13:17:56Z   10.0   0.0    False
# 2022-06-03T13:17:57Z   10.0   0.0    False
# 2022-06-03T13:17:58Z   10.0   0.0    False
# ...                     ...   ...      ...
# 2022-06-03T13:51:01Z   10.0   0.0    False
# 2022-06-03T13:51:02Z    8.0   4.0    False
# 2022-06-03T13:51:03Z    7.0   6.0    False
# 2022-06-03T13:51:04Z   10.0   0.0    False
# 2022-06-03T13:51:05Z   10.0   0.0    False
#
# [1992 rows x 3 columns]

# %%
table_3x = pd.concat([table]*3)
table_3x.sort_values(by=['timestamp'], inplace=True)
table_3x
# Out:
# isAnomaly             False  True  Anomaly
# timestamp
# 2022-06-03T13:17:54Z   10.0   0.0    False
# 2022-06-03T13:17:54Z   10.0   0.0    False
# 2022-06-03T13:17:54Z   10.0   0.0    False
# 2022-06-03T13:17:55Z   10.0   0.0    False
# 2022-06-03T13:17:55Z   10.0   0.0    False
# ...                     ...   ...      ...
# 2022-06-03T13:51:04Z   10.0   0.0    False
# 2022-06-03T13:51:04Z   10.0   0.0    False
# 2022-06-03T13:51:05Z   10.0   0.0    False
# 2022-06-03T13:51:05Z   10.0   0.0    False
# 2022-06-03T13:51:05Z   10.0   0.0    False
#
# [5976 rows x 3 columns]

# %%
table_3x.reset_index(inplace=True)

# %%
anomaly = table_3x[table_3x['Anomaly']==True]
# ts = anomaly['timestamp']

# %%
anomaly
# Out:
# isAnomaly             timestamp  False  True  Anomaly
# 48         2022-06-03T13:18:10Z    3.0  14.0     True
# 49         2022-06-03T13:18:10Z    3.0  14.0     True
# 50         2022-06-03T13:18:10Z    3.0  14.0     True
# 489        2022-06-03T13:20:37Z    5.0  10.0     True
# 490        2022-06-03T13:20:37Z    5.0  10.0     True
# ...                         ...    ...   ...      ...
# 5731       2022-06-03T13:49:44Z    6.0   8.0     True
# 5732       2022-06-03T13:49:44Z    6.0   8.0     True
# 5868       2022-06-03T13:50:30Z    5.0  10.0     True
# 5869       2022-06-03T13:50:30Z    5.0  10.0     True
# 5870       2022-06-03T13:50:30Z    5.0  10.0     True
#
# [84 rows x 4 columns]

# %%
anomaly.to_csv('anomaly2.csv')

# %%
pos = pd.read_csv(
    'pos.csv', 
)
pos
# Out:
#                   timestamp  latitude  longitude
# 0      2022-06-03T13:10:53Z  13.79474  100.65597
# 1      2022-06-03T13:11:02Z  13.79474  100.65597
# 2      2022-06-03T13:11:10Z  13.79474  100.65597
# 3      2022-06-03T13:11:10Z  13.79476  100.65597
# 4      2022-06-03T13:11:10Z  13.79477  100.65629
# ...                     ...       ...        ...
# 16147  2022-06-03T17:10:40Z  13.80371  100.66728
# 16148  2022-06-03T17:10:41Z  13.80371  100.66728
# 16149  2022-06-03T17:10:42Z  13.80371  100.66728
# 16150  2022-06-03T17:10:43Z  13.80371  100.66728
# 16151  2022-06-03T17:10:44Z  13.80371  100.66728
#
# [16152 rows x 3 columns]

# %%
pos_ano = table[table['Anomaly']==True].merge(pos, how='left', on='timestamp')

# %%
pos_ano.drop_duplicates(inplace=True)
pos_ano
# Out:
#                timestamp  False  True  Anomaly  latitude  longitude
# 0   2022-06-03T13:18:10Z    3.0  14.0     True  13.80130  100.64848
# 2   2022-06-03T13:20:37Z    5.0  10.0     True  13.81249  100.64656
# 4   2022-06-03T13:21:27Z    6.0   8.0     True  13.81607  100.64131
# 6   2022-06-03T13:23:20Z    6.0   8.0     True  13.82103  100.63314
# 8   2022-06-03T13:23:27Z    5.0  10.0     True  13.82121  100.63290
# 10  2022-06-03T13:23:28Z    6.0   8.0     True  13.82126  100.63285
# 12  2022-06-03T13:26:59Z    6.0   8.0     True  13.82491  100.62885
# 14  2022-06-03T13:27:00Z    6.0   8.0     True  13.82493  100.62883
# 16  2022-06-03T13:27:05Z    6.0   8.0     True  13.82510  100.62866
# 18  2022-06-03T13:27:07Z    6.0   8.0     True  13.82519  100.62857
# 20  2022-06-03T13:27:11Z    6.0   8.0     True  13.82539  100.62836
# 22  2022-06-03T13:29:06Z    4.0  12.0     True  13.82201  100.63352
# 24  2022-06-03T13:41:53Z    4.0  12.0     True  13.82200  100.63363
# 26  2022-06-03T13:41:54Z    3.0  14.0     True  13.82199  100.63365
# 28  2022-06-03T13:42:12Z    5.0  10.0     True  13.82162  100.63380
# 30  2022-06-03T13:42:13Z    6.0   8.0     True  13.82160  100.63381
# 32  2022-06-03T13:42:30Z    6.0   8.0     True  13.82121  100.63434
# 34  2022-06-03T13:43:01Z    3.0  14.0     True  13.82063  100.63414
# 36  2022-06-03T13:43:02Z    6.0   8.0     True  13.82062  100.63413
# 38  2022-06-03T13:44:32Z    6.0   8.0     True  13.81792  100.63849
# 40  2022-06-03T13:44:37Z    3.0  14.0     True  13.81783  100.63866
# 42  2022-06-03T13:45:12Z    6.0   8.0     True  13.81695  100.64019
# 43  2022-06-03T13:45:12Z    6.0   8.0     True  13.81692  100.64024
# 46  2022-06-03T13:49:24Z    6.0   8.0     True  13.81609  100.64163
# 48  2022-06-03T13:49:25Z    5.0  10.0     True  13.81608  100.64169
# 50  2022-06-03T13:49:40Z    4.0  12.0     True  13.81576  100.64224
# 52  2022-06-03T13:49:41Z    6.0   8.0     True  13.81576  100.64225
# 54  2022-06-03T13:49:44Z    6.0   8.0     True  13.81566  100.64210
# 56  2022-06-03T13:50:30Z    5.0  10.0     True  13.81873  100.63671

# %%
img_class = pd.read_csv(
    'image_classification.csv', 
    skiprows=1, 
    names=['timestamp','image_class','image_name']
)
img_class
# Out:
#                timestamp   image_class  \
# 0   2022-06-03T13:18:10Z  longitudinal
# 1   2022-06-03T13:20:37Z       pothole
# 2   2022-06-03T13:21:27Z       lateral
# 3   2022-06-03T13:23:20Z      repaired
# 4   2022-06-03T13:23:27Z       pothole
# 5   2022-06-03T13:23:28Z       pothole
# 6   2022-06-03T13:26:59Z       pothole
# 7   2022-06-03T13:27:00Z       pothole
# 8   2022-06-03T13:27:05Z  longitudinal
# 9   2022-06-03T13:27:07Z  longitudinal
# 10  2022-06-03T13:27:11Z  longitudinal
# 11  2022-06-03T13:29:06Z       manhole
# 12  2022-06-03T13:41:53Z     speedbump
# 13  2022-06-03T13:41:54Z     speedbump
# 14  2022-06-03T13:42:12Z     speedbump
# 15  2022-06-03T13:42:13Z     speedbump
# 16  2022-06-03T13:42:30Z     speedbump
# 17  2022-06-03T13:43:01Z     speedbump
# 18  2022-06-03T13:43:02Z     speedbump
# 19  2022-06-03T13:44:32Z     speedbump
# 20  2022-06-03T13:44:37Z     speedbump
# 21  2022-06-03T13:45:12Z     speedbump
# 22  2022-06-03T13:49:24Z       lateral
# 23  2022-06-03T13:49:25Z       lateral
# 24  2022-06-03T13:49:40Z       lateral
# 25  2022-06-03T13:49:41Z       lateral
# 26  2022-06-03T13:49:44Z       lateral
# 27  2022-06-03T13:50:30Z       lateral
#
#                                            image_name
# 0   https://roadanomalydetect.blob.core.windows.ne...
# 1   https://roadanomalydetect.blob.core.windows.ne...
# 2   https://roadanomalydetect.blob.core.windows.ne...
# 3   https://roadanomalydetect.blob.core.windows.ne...
# 4   https://roadanomalydetect.blob.core.windows.ne...
# 5   https://roadanomalydetect.blob.core.windows.ne...
# 6   https://roadanomalydetect.blob.core.windows.ne...
# 7   https://roadanomalydetect.blob.core.windows.ne...
# 8   https://roadanomalydetect.blob.core.windows.ne...
# 9   https://roadanomalydetect.blob.core.windows.ne...
# 10  https://roadanomalydetect.blob.core.windows.ne...
# 11  https://roadanomalydetect.blob.core.windows.ne...
# 12  https://roadanomalydetect.blob.core.windows.ne...
# 13  https://roadanomalydetect.blob.core.windows.ne...
# 14  https://roadanomalydetect.blob.core.windows.ne...
# 15  https://roadanomalydetect.blob.core.windows.ne...
# 16  https://roadanomalydetect.blob.core.windows.ne...
# 17  https://roadanomalydetect.blob.core.windows.ne...
# 18  https://roadanomalydetect.blob.core.windows.ne...
# 19  https://roadanomalydetect.blob.core.windows.ne...
# 20  https://roadanomalydetect.blob.core.windows.ne...
# 21  https://roadanomalydetect.blob.core.windows.ne...
# 22  https://roadanomalydetect.blob.core.windows.ne...
# 23  https://roadanomalydetect.blob.core.windows.ne...
# 24  https://roadanomalydetect.blob.core.windows.ne...
# 25  https://roadanomalydetect.blob.core.windows.ne...
# 26  https://roadanomalydetect.blob.core.windows.ne...
# 27  https://roadanomalydetect.blob.core.windows.ne...

# %%
df_final = pos_ano.merge(img_class, how='inner', on='timestamp')
df_final
# Out:
#                timestamp  False  True  Anomaly  latitude  longitude  \
# 0   2022-06-03T13:18:10Z    3.0  14.0     True  13.80130  100.64848
# 1   2022-06-03T13:20:37Z    5.0  10.0     True  13.81249  100.64656
# 2   2022-06-03T13:21:27Z    6.0   8.0     True  13.81607  100.64131
# 3   2022-06-03T13:23:20Z    6.0   8.0     True  13.82103  100.63314
# 4   2022-06-03T13:23:27Z    5.0  10.0     True  13.82121  100.63290
# 5   2022-06-03T13:23:28Z    6.0   8.0     True  13.82126  100.63285
# 6   2022-06-03T13:26:59Z    6.0   8.0     True  13.82491  100.62885
# 7   2022-06-03T13:27:00Z    6.0   8.0     True  13.82493  100.62883
# 8   2022-06-03T13:27:05Z    6.0   8.0     True  13.82510  100.62866
# 9   2022-06-03T13:27:07Z    6.0   8.0     True  13.82519  100.62857
# 10  2022-06-03T13:27:11Z    6.0   8.0     True  13.82539  100.62836
# 11  2022-06-03T13:29:06Z    4.0  12.0     True  13.82201  100.63352
# 12  2022-06-03T13:41:53Z    4.0  12.0     True  13.82200  100.63363
# 13  2022-06-03T13:41:54Z    3.0  14.0     True  13.82199  100.63365
# 14  2022-06-03T13:42:12Z    5.0  10.0     True  13.82162  100.63380
# 15  2022-06-03T13:42:13Z    6.0   8.0     True  13.82160  100.63381
# 16  2022-06-03T13:42:30Z    6.0   8.0     True  13.82121  100.63434
# 17  2022-06-03T13:43:01Z    3.0  14.0     True  13.82063  100.63414
# 18  2022-06-03T13:43:02Z    6.0   8.0     True  13.82062  100.63413
# 19  2022-06-03T13:44:32Z    6.0   8.0     True  13.81792  100.63849
# 20  2022-06-03T13:44:37Z    3.0  14.0     True  13.81783  100.63866
# 21  2022-06-03T13:45:12Z    6.0   8.0     True  13.81695  100.64019
# 22  2022-06-03T13:45:12Z    6.0   8.0     True  13.81692  100.64024
# 23  2022-06-03T13:49:24Z    6.0   8.0     True  13.81609  100.64163
# 24  2022-06-03T13:49:25Z    5.0  10.0     True  13.81608  100.64169
# 25  2022-06-03T13:49:40Z    4.0  12.0     True  13.81576  100.64224
# 26  2022-06-03T13:49:41Z    6.0   8.0     True  13.81576  100.64225
# 27  2022-06-03T13:49:44Z    6.0   8.0     True  13.81566  100.64210
# 28  2022-06-03T13:50:30Z    5.0  10.0     True  13.81873  100.63671
#
#      image_class                                         image_name
# 0   longitudinal  https://roadanomalydetect.blob.core.windows.ne...
# 1        pothole  https://roadanomalydetect.blob.core.windows.ne...
# 2        lateral  https://roadanomalydetect.blob.core.windows.ne...
# 3       repaired  https://roadanomalydetect.blob.core.windows.ne...
# 4        pothole  https://roadanomalydetect.blob.core.windows.ne...
# 5        pothole  https://roadanomalydetect.blob.core.windows.ne...
# 6        pothole  https://roadanomalydetect.blob.core.windows.ne...
# 7        pothole  https://roadanomalydetect.blob.core.windows.ne...
# 8   longitudinal  https://roadanomalydetect.blob.core.windows.ne...
# 9   longitudinal  https://roadanomalydetect.blob.core.windows.ne...
# 10  longitudinal  https://roadanomalydetect.blob.core.windows.ne...
# 11       manhole  https://roadanomalydetect.blob.core.windows.ne...
# 12     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 13     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 14     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 15     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 16     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 17     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 18     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 19     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 20     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 21     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 22     speedbump  https://roadanomalydetect.blob.core.windows.ne...
# 23       lateral  https://roadanomalydetect.blob.core.windows.ne...
# 24       lateral  https://roadanomalydetect.blob.core.windows.ne...
# 25       lateral  https://roadanomalydetect.blob.core.windows.ne...
# 26       lateral  https://roadanomalydetect.blob.core.windows.ne...
# 27       lateral  https://roadanomalydetect.blob.core.windows.ne...
# 28       lateral  https://roadanomalydetect.blob.core.windows.ne...

# %%
df_final[['timestamp','latitude', 'longitude', 'image_class','image_name']].to_csv('anomaly_final.csv', index=False)
